# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df=pd.read_csv("C:/Users/Lenovo/Desktop/digikala/1/data/train.csv")
test_df=pd.read_csv("C:/Users/Lenovo/Desktop/digikala/1/data/test.csv")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68840 entries, 0 to 68839
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   68840 non-null  int64
#  1   product_description  68840 non-null  object
#  2   price                68840 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.6+ MB

# %%
train_df.isnull().sum()
# Out:
# id                     0
# product_description    0
# price                  0
# dtype: int64

# %%
train_df.head()
# Out:
#    id                                product_description    price
# 0   0  {'مشخصات فنی': 'متراژ: 150 سانتی متر\r\nپورت ی...  1080000
# 1   1  {'مشخصات فنی': 'CABLE LENTH:\r\n10feet \\/3M\r...   990000
# 2   2  {'مشخصات فنی': 'نوع کابل: KVM USB\r\nطول کابل:...  1680000
# 3   3       {'دسته بندی': 'کابل کمبو', 'برند': 'متفرقه'}  4500000
# 4   4  {'مشخصات فنی': 'کیبورد: 6pin Mini-DIN Male - P...   700000

# %%
train_df.set_index("id",inplace=True)

# %%
train_df_x= train_df.drop("price",axis=1)
train_df_y=train_df["price"]
train_df_y=train_df_y.to_frame(name="price")

# %%
train_df_x.head()
# Out:
#                                   product_description
# id
# 0   {'مشخصات فنی': 'متراژ: 150 سانتی متر\r\nپورت ی...
# 1   {'مشخصات فنی': 'CABLE LENTH:\r\n10feet \\/3M\r...
# 2   {'مشخصات فنی': 'نوع کابل: KVM USB\r\nطول کابل:...
# 3        {'دسته بندی': 'کابل کمبو', 'برند': 'متفرقه'}
# 4   {'مشخصات فنی': 'کیبورد: 6pin Mini-DIN Male - P...

# %%
train_df_y.head()
# Out:
#       price
# id
# 0   1080000
# 1    990000
# 2   1680000
# 3   4500000
# 4    700000

# %%
train_df_x["product_description"]
# Out:
# id
# 0        {'مشخصات فنی': 'متراژ: 150 سانتی متر\r\nپورت ی...
# 1        {'مشخصات فنی': 'CABLE LENTH:\r\n10feet \\/3M\r...
# 2        {'مشخصات فنی': 'نوع کابل: KVM USB\r\nطول کابل:...
# 3             {'دسته بندی': 'کابل کمبو', 'برند': 'متفرقه'}
# 4        {'مشخصات فنی': 'کیبورد: 6pin Mini-DIN Male - P...
#                                ...
# 68835    {'دسته بندی': 'شارژر تبلت و موبایل', 'برند': '...
# 68836    {'دسته بندی': 'شارژر تبلت و موبایل', 'برند': '...
# 68837    {'دسته بندی': 'شارژر تبلت و موبایل', 'برند': '...
# 68838    {'کابل همراه': ['لایتنینگ'], 'ولتاژ خروجی': ['...
# 68839    {'وزن': 'یک سانتی\u200cمتر', 'درگاه\u200cهای ا...
# Name: product_description, Length: 68840, dtype: object

# %%
pd.set_option("max_colwidth", None)
train_df_x["product_description"].to_frame().head()
# Out:
#                                                                                                                                                                                                                                                                                               product_description
# id
# 0                                                                                                                                                                                                             {'مشخصات فنی': 'متراژ: 150 سانتی متر\r\nپورت یو اس بی', 'دسته بندی': 'کابل کمبو', 'برند': 'متفرقه'}
# 1   {'مشخصات فنی': 'CABLE LENTH:\r\n10feet \\/3M\r\nPC SIDE CONNECTORS_CONNECTED TO PC : \r\nPS\\/2 Keyboard mini-Din 6 pin, male\r\nPS\\/2 Mouse Mini-Din 6 pin, male\r\nVGA HDDB 15pin, male\r\nKVM SIDE CONNECTORS-CONNECTED TO KVM SWITCH: \r\nHDDB 15pin, male', 'دسته بندی': 'کابل کمبو', 'برند': 'ادیمکس'}
# ...

# %%
train_df_x["product_description"] = train_df_x["product_description"].apply(lambda x : dict(eval(x)) )
df3 = train_df_x["product_description"].apply(pd.Series )

# %%
df3.columns
# Out:
# Index(['مشخصات فنی', 'دسته بندی', 'برند', 'کارکرد', 'دستگاه‌های سازگار',
#        'سایر توضیحات', 'حجم', 'ابعاد', 'وزن', 'قابلیت‌های گام‌شمار',
#        ...
#        'عمر باتری محفظه شارژ', 'منبع تغذیه هدفون', 'امکانات ارتباطی',
#        'منبع تغذیه فرستنده', 'سایر توضیحات کابل', 'بازه طول کابل',
#        'نوع کانکتور', 'سایر توضیحات مبدل', 'پشتیبانی از', 'قابلیت‌های شارژر'],
#       dtype='object', length=1480)

# %%
pd.set_option('display.max_columns', None)
df3.head()
# Out:
#                                                                                                                                                                                                                                       مشخصات فنی  \
# id
# 0                                                                                                                                                                                                          متراژ: 150 سانتی متر\r\nپورت یو اس بی
# 1   CABLE LENTH:\r\n10feet \/3M\r\nPC SIDE CONNECTORS_CONNECTED TO PC : \r\nPS\/2 Keyboard mini-Din 6 pin, male\r\nPS\/2 Mouse Mini-Din 6 pin, male\r\nVGA HDDB 15pin, male\r\nKVM SIDE CONNECTORS-CONNECTED TO KVM SWITCH: \r\nHDDB 15pin, male
# 2                                                                                                                                                                                                         نوع کابل: KVM USB\r\nطول کابل: 1.5 متر
# ...

# %%
df3.shape
# Out:
# (68840, 1480)

# %%
nan_cols=df3.columns[df3.isnull().sum()>60000]

# %%
nan_cols
# Out:
# Index(['مشخصات فنی', 'کارکرد', 'دستگاه‌های سازگار', 'سایر توضیحات', 'حجم',
#        'قابلیت‌های گام‌شمار', 'مشخصات باتری', 'نرم افزار یا اپلیکیشن سازگار',
#        'سایر امکانات', 'حافظه داخلی',
#        ...
#        'عمر باتری محفظه شارژ', 'منبع تغذیه هدفون', 'امکانات ارتباطی',
#        'منبع تغذیه فرستنده', 'سایر توضیحات کابل', 'بازه طول کابل',
#        'نوع کانکتور', 'سایر توضیحات مبدل', 'پشتیبانی از', 'قابلیت‌های شارژر'],
#       dtype='object', length=1473)

# %%
nan_columns=df3.isnull().sum()/df3.shape[0]

# %%
nan_cols=df3.columns[nan_columns>.5]

# %%
nan_cols
# Out:
# Index(['مشخصات فنی', 'کارکرد', 'دستگاه‌های سازگار', 'سایر توضیحات', 'حجم',
#        'ابعاد', 'قابلیت‌های گام‌شمار', 'مشخصات باتری',
#        'نرم افزار یا اپلیکیشن سازگار', 'سایر امکانات',
#        ...
#        'عمر باتری محفظه شارژ', 'منبع تغذیه هدفون', 'امکانات ارتباطی',
#        'منبع تغذیه فرستنده', 'سایر توضیحات کابل', 'بازه طول کابل',
#        'نوع کانکتور', 'سایر توضیحات مبدل', 'پشتیبانی از', 'قابلیت‌های شارژر'],
#       dtype='object', length=1477)

# %%
df3.columns.size
# Out:
# 1480

# %%
## so as you can see there are just 4 columns(1480-1476) that have null values less than 60000

# %%
df3.drop(nan_cols,axis=1,inplace=True)

# %%
df3.columns
# Out:
# Index(['دسته بندی', 'برند', 'وزن'], dtype='object')

# %%
df3.isnull().sum()
# Out:
# دسته بندی        0
# برند             0
# وزن          31156
# dtype: int64

# %%
result_x = pd.concat([train_df_x, df3], axis=1).drop('product_description', axis=1)

# %%
result_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68840 entries, 0 to 68839
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   دسته بندی  68840 non-null  object
#  1   برند       68840 non-null  object
#  2   وزن        37684 non-null  object
# dtypes: object(3)
# memory usage: 2.1+ MB

# %%
result_x["دسته بندی"].value_counts()
# Out:
# شارژر تبلت و موبایل       4380
# کابل و مبدل               4327
# هدفون، هدست و هندزفری     4148
# محافظ لنز گوشی موبایل     4114
# فلش مموری                 2754
#                           ...
# ریسوگراف                     9
# لوازم جانبی NAS و سرور       9
# گیت وی                       9
# کاغذ چاپ سریع                9
# کابل کمبو                    6
# Name: دسته بندی, Length: 180, dtype: int64

# %%
result_x["برند"].value_counts()
# Out:
# متفرقه                33127
# هورس                   1332
# باسئوس                  946
# لنوو                    721
# ماهوت                   623
#                       ...
# آی بی ام                  1
# ایسر پریدیتور             1
# ایکس وی ایکس              1
# فرست بلاد انلی گیم        1
# ورسون                     1
# Name: برند, Length: 1658, dtype: int64

# %%
result_x["وزن"].value_counts()
# Out:
# ضد خش             1610
# تی‌شرت و شلوار    1580
# رومی              1559
# بند قابل تعویض    1496
# یک سانتی‌متر      1354
#                   ...
# آمریکا               1
#  با باتری 385        1
# 1.167                1
# 0.731                1
# 130                  1
# Name: وزن, Length: 1826, dtype: int64

# %%
## وزن columns has lots of irrelevant values so we drop in from result_x

# %%
result_x.drop("وزن" , axis=1,inplace=True)

# %%
result_x.head(10)
# Out:
#     دسته بندی     برند
# id
# 0   کابل کمبو   متفرقه
# 1   کابل کمبو   ادیمکس
# 2   کابل کمبو   متفرقه
# 3   کابل کمبو   متفرقه
# 4   کابل کمبو  دی-لینک
# 5   کابل کمبو   متفرقه
# 6    ریسوگراف   متفرقه
# 7    ریسوگراف   متفرقه
# 8    ریسوگراف   متفرقه
# 9    ریسوگراف   متفرقه

# %%
result_x["برند"].isnull().sum()
# Out:
# 0

# %%
result_x["دسته بندی"].isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
berand = label_encoder.fit_transform(result_x["برند"])

np.save('classes.npy', label_encoder.classes_)
berand
# Out:
# array([1033,   99, 1033, ..., 1062,  734, 1152])

# %%
##np.set_printoptions(threshold=np.inf)
berand
# Out:
# array([1033,   99, 1033, ..., 1062,  734, 1152])

# %%
dastebandi = label_encoder.fit_transform(result_x["دسته بندی"])
## np.save('classes.npy', label_encoder.classes_)
dastebandi
# Out:
# array([151, 151, 151, ...,  71,  71,  71])

# %%
result_x.apply(LabelEncoder().fit_transform)
# Out:
#        دسته بندی  برند
# id
# 0            151  1033
# 1            151    99
# 2            151  1033
# 3            151  1033
# 4            151   656
# ...          ...   ...
# 68835         71  1075
# 68836         71   156
# 68837         71  1062
# 68838         71   734
# 68839         71  1152
#
# [68840 rows x 2 columns]

# %%
label_encoder.transform(result_x["دسته بندی"].to_frame())
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# array([151, 151, 151, ...,  71,  71,  71])

# %%
result_x["دسته بندی"].value_counts()
# Out:
# شارژر تبلت و موبایل       4380
# کابل و مبدل               4327
# هدفون، هدست و هندزفری     4148
# محافظ لنز گوشی موبایل     4114
# فلش مموری                 2754
#                           ...
# ریسوگراف                     9
# لوازم جانبی NAS و سرور       9
# گیت وی                       9
# کاغذ چاپ سریع                9
# کابل کمبو                    6
# Name: دسته بندی, Length: 180, dtype: int64

# %%
a= result_x["دسته بندی"]

# %%
a
# Out:
# id
# 0                  کابل کمبو
# 1                  کابل کمبو
# 2                  کابل کمبو
# 3                  کابل کمبو
# 4                  کابل کمبو
#                 ...
# 68835    شارژر تبلت و موبایل
# 68836    شارژر تبلت و موبایل
# 68837    شارژر تبلت و موبایل
# 68838    شارژر تبلت و موبایل
# 68839    شارژر تبلت و موبایل
# Name: دسته بندی, Length: 68840, dtype: object

# %%
a[1]
# Out:
# 'کابل کمبو'

# %%
a[3445]
# Out:
# 'دستگاه کنترل تردد'

# %%
b= result_x["برند"]

# %%
b[2]
# Out:
# 'متفرقه'

# %%
b[43]
# Out:
# 'پاناسونیک'

# %%
berand
# Out:
# array([1033,   99, 1033, ..., 1062,  734, 1152])

# %%
dastebandi
# Out:
# array([151, 151, 151, ...,  71,  71,  71])

# %%
berand=pd.DataFrame(berand,columns=["berand"])

# %%
dastebandi=pd.DataFrame(dastebandi,columns=["dastebandi"])

# %%
##dastebandi

# %%
final_x_train= pd.concat([berand,dastebandi],axis=1)

# %%
#final_x_train

# %%
test_df.head()
# Out:
#    id  \
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4
#
#                                                                                                                                                                                                                                                                                                             product_description
# 0                                                                                                               {'سازگار با': 'C21N1401\r\nX455', 'ولتاژ باتری': '7.6', 'ظرفیت باتری': 'کولا', 'مناسب برای لپ\u200cتاپ\u200cهای برند': ['Asus'], 'محل قرارگیری': ['داخلی'], 'دسته بندی': 'باتری لپ\u200cتاپ', 'برند': 'متفرقه'}
# ...

# %%
test_df["product_description"] =test_df["product_description"].apply(lambda x : dict(eval(x)) )
df4 = test_df["product_description"].apply(pd.Series )

# %%
df4=df4[["برند","دسته بندی"]]

# %%
##label_encoder = LabelEncoder()

##label_encoder.classes_ = np.load('classes.npy',allow_pickle=True)

# %%
df4.apply(LabelEncoder().fit_transform)
# Out:
#        برند  دسته بندی
# 0       819         17
# 1       819         17
# 2      1238          7
# 3       819         17
# 4       819         17
# ...     ...        ...
# 34257   300         71
# 34258   819         71
# 34259   576         71
# 34260   819         71
# 34261   639         71
#
# [34262 rows x 2 columns]

# %%
#berand_test = label_encoder.fit_transform(df4["برند"])
#dastebandi_test = label_encoder.fit_transform(df4["دسته بندی"])

#berand_test=pd.DataFrame(berand_test,columns=["berand"])
#dastebandi_test=pd.DataFrame(dastebandi_test,columns=["dastebandi"])

# %%
# x_test = pd.concat([berand_test,dastebandi_test],axis=1)

# %%
df4=df4.apply(LabelEncoder().fit_transform)

# %%
final_x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68840 entries, 0 to 68839
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   berand      68840 non-null  int32
#  1   dastebandi  68840 non-null  int32
# dtypes: int32(2)
# memory usage: 537.9 KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34262 entries, 0 to 34261
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   برند       34262 non-null  int32
#  1   دسته بندی  34262 non-null  int32
# dtypes: int32(2)
# memory usage: 267.8 KB

# %%
train_df_y
# Out:
#           price
# id
# 0       1080000
# 1        990000
# 2       1680000
# 3       4500000
# 4        700000
# ...         ...
# 68835   2530000
# 68836  22000000
# 68837   4000000
# 68838   4300000
# 68839    950000
#
# [68840 rows x 1 columns]

# %%
df4.shape
# Out:
# (34262, 2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
## when we don't have x_test
## X_train, X_test, y_train, y_test = train_test_split(final_x_train , train_df_y , test_size=0.3, random_state=42)

# %%
model= LinearRegression()

# %%
model.fit(final_x_train ,train_df_y)
# Out:
# LinearRegression()

# %%
#X_train.shape ,y_train.shape

# %%
#X_test.shape ,y_test.shape

# %%
predict = model.predict(df4)

# %%
predict
# Out:
# array([[12921885.12245343],
#        [12921885.12245343],
#        [ 3220763.70081625],
#        ...,
#        [22119644.57915876],
#        [16923191.82539915],
#        [20772416.0874433 ]])

# %%
prediction=pd.DataFrame(predict, columns=["price"])

# %%
prediction
# Out:
#               price
# 0      1.292189e+07
# 1      1.292189e+07
# 2      3.220764e+06
# 3      1.292189e+07
# 4      1.292189e+07
# ...             ...
# 34257  2.802179e+07
# 34258  1.692319e+07
# 34259  2.211964e+07
# 34260  1.692319e+07
# 34261  2.077242e+07
#
# [34262 rows x 1 columns]

# %%
final_x_train.shape
# Out:
# (68840, 2)

# %%
prediction.shape
# Out:
# (34262, 1)

# %%
train_df_n=train_df.reset_index()

# %%
train_df_n
# Out:
#           id  \
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 68835  68835
# 68836  68836
# 68837  68837
# 68838  68838
# 68839  68839
#
#                                                                                                                                                                                                                                                                                                        product_description  \
# 0                                                                                                                                                                                                                      {'مشخصات فنی': 'متراژ: 150 سانتی متر\r\nپورت یو اس بی', 'دسته بندی': 'کابل کمبو', 'برند': 'متفرقه'}
# ...

# %%
prediction["id"]=train_df_n["id"]

# %%
prediction
# Out:
#               price     id
# id
# 0      1.292189e+07      0
# 1      1.292189e+07      1
# 2      3.220764e+06      2
# 3      1.292189e+07      3
# 4      1.292189e+07      4
# ...             ...    ...
# 34257  2.802179e+07  34257
# 34258  1.692319e+07  34258
# 34259  2.211964e+07  34259
# 34260  1.692319e+07  34260
# 34261  2.077242e+07  34261
#
# [34262 rows x 2 columns]

# %%
prediction= prediction[["id","price"]]

# %%
prediction.set_index("id",inplace=True)

# %%
prediction
# Out:
#               price
# id
# 0      1.292189e+07
# 1      1.292189e+07
# 2      3.220764e+06
# 3      1.292189e+07
# 4      1.292189e+07
# ...             ...
# 34257  2.802179e+07
# 34258  1.692319e+07
# 34259  2.211964e+07
# 34260  1.692319e+07
# 34261  2.077242e+07
#
# [34262 rows x 1 columns]

# %%
prediction.to_csv("output.csv")

# %%
#y_test["prediction"]=predict
